# %% [markdown]
# # Bond Scores

# %% [markdown]
# ### Setup

# %%
import prep

# %%
from destijl.style import use_style
# %pylab inline
use_style()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfs = prep.prep_all_films()

# %% [markdown]
# ## Scores

# %%
# Overall Score
prep.plot_attribute_across_film(dfs, "Overall");

# %%
# Problematicness
prep.plot_attribute_across_film(dfs, "Problematic");

# %%
# Memery
prep.plot_attribute_across_film(dfs, "Memery");

# %%
prep.plot_multiple_attributes(dfs, ["Overall", "Problematic", "Memery"], "mean")

# %% [markdown]
# ## The Rest

# %%
attributes = [
    'Opening Scene',
    'Theme Song',
    'James Bond',
    'Bond Girl',
    'Allies and Supporting Cast',
    'Villain & Henchmen',
    'Car and Gadgets',
    'Locations',
    'Presentation',
    'Plot / Sophisticated Movie Critique',
]
for a in attributes:
    prep.plot_attribute_across_film(dfs, a);
